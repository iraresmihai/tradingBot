# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.requests import StockQuotesRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime

# %%
import json, websockets

# %%
import asyncio

# %%
URL = "wss://stream.data.alpaca.markets/v2/test"
KEY = "PKLMGS5UW4MWAIBQHAOGE4GBDT"
SECRET = "TU3iR8UA3fZpPWw89y5d4gD1tHkDCBEnA2sneYuThpP" 

from alpaca.data.historical import StockHistoricalDataClient

client = StockHistoricalDataClient(
    api_key=KEY,
    secret_key=SECRET
)

request_params = StockBarsRequest(
    symbol_or_symbols=["AAPL"],
    timeframe=TimeFrame.Day,
    start=datetime(2024, 1, 1),
    end=datetime(2024, 1, 7)
)

bars = client.get_stock_bars(request_params)
print(bars.df)
'''
request_params2 = StockQuotesRequest(
    symbol_or_symbols=["AAPL"],
    start=datetime(2024, 1, 2),
    end=datetime(2024, 1, 7),
    limit = 10
)

quotes = client.get_stock_quotes(request_params2)
print(quotes.df)
'''
# Out:
#                                     open      high      low   close  \
# symbol timestamp
# AAPL   2024-01-02 05:00:00+00:00  187.15  188.4400  183.885  185.64
#        2024-01-03 05:00:00+00:00  184.22  185.8800  183.430  184.25
#        2024-01-04 05:00:00+00:00  182.15  183.0872  180.880  181.91
#        2024-01-05 05:00:00+00:00  181.99  182.7600  180.170  181.18
#
#                                       volume  trade_count        vwap
# symbol timestamp
# AAPL   2024-01-02 05:00:00+00:00  82496943.0    1009074.0  185.846233
#        2024-01-03 05:00:00+00:00  58418916.0     656956.0  184.319693
#        2024-01-04 05:00:00+00:00  71992243.0     712850.0  182.013085
#        2024-01-05 05:00:00+00:00  62379661.0     682335.0  181.483937
# '\nrequest_params2 = StockQuotesRequest(\n    symbol_or_symbols=["AAPL"],\n    start=datetime(2024, 1, 2),\n    end=datetime(2024, 1, 7),\n    limit = 10\n)\n\nquotes = client.get_stock_quotes(request_params2)\nprint(quotes.df)\n'

# %%
client

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

trading_client = TradingClient(KEY, SECRET, paper=True)

# preparing market order
market_order_data = MarketOrderRequest(
                    symbol="SPY",
                    qty=0.023,
                    side=OrderSide.SELL,
                    time_in_force=TimeInForce.DAY,
                    client_order_id='my_first_order2',
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )

my_order = trading_client.get_order_by_client_id('my_first_order2')
print('Got order #{}'.format(my_order.id))
# Out:
# Got order #dd584aeb-575a-4ec9-8939-752965c8189c

# %%
from alpaca.data.requests import StockQuotesRequest
from datetime import datetime

request_params = StockQuotesRequest(
    symbol_or_symbols=["AAPL"],
    start=datetime(2024, 1, 2),
    end=datetime(2024, 1, 3),
)

quotes = client.get_stock_quotes(request_params)
df = quotes.df

# Calculate the spread
df['spread'] = df['ask_price'] - df['bid_price']

print(df[['bid_price', 'ask_price', 'spread']])
# Out:
#                                          bid_price  ask_price  spread
# symbol timestamp
# AAPL   2024-01-02 09:00:00.004465+00:00     190.05     192.92    2.87
#        2024-01-02 09:00:00.004480+00:00     190.05     191.84    1.79
#        2024-01-02 09:00:00.004524+00:00     190.05     191.68    1.63
#        2024-01-02 09:00:00.004531+00:00     190.05     191.68    1.63
#        2024-01-02 09:00:00.005234+00:00     190.05     191.84    1.79
# ...                                            ...        ...     ...
#        2024-01-02 23:58:45.417307+00:00     185.29     185.30    0.01
#        2024-01-02 23:58:54.552442+00:00     185.29     185.30    0.01
#        2024-01-02 23:58:56.361452+00:00     185.29     185.31    0.02
#        2024-01-02 23:59:19.907198+00:00     185.29     185.31    0.02
#        2024-01-02 23:59:29.595405+00:00     185.29     185.31    0.02
#
# [1695607 rows x 3 columns]

# %%
client = StockHistoricalDataClient(
    api_key=KEY,
    secret_key=SECRET
)

request_params = StockBarsRequest(
    symbol_or_symbols=["AAPL", "TSLA"],
    timeframe=TimeFrame.Minute,
    start=datetime(2024, 1, 1),
    end=datetime(2024, 1, 7)
)

bars = client.get_stock_bars(request_params)
print(bars.df)

df = bars.df
df.to_parquet("aapl_tsla_daily_2024.parquet")
# Out:
#                                     open    high     low     close   volume  \
# symbol timestamp
# AAPL   2024-01-02 09:00:00+00:00  191.52  191.52  190.00  190.2000  18933.0
#        2024-01-02 09:01:00+00:00  190.11  190.13  190.00  190.0000   8562.0
#        2024-01-02 09:02:00+00:00  189.90  189.90  189.82  189.8200   5355.0
#        2024-01-02 09:03:00+00:00  189.87  189.87  189.80  189.8700   4405.0
#        2024-01-02 09:04:00+00:00  189.90  189.95  189.90  189.9000   2225.0
# ...                                  ...     ...     ...       ...      ...
# TSLA   2024-01-06 00:55:00+00:00  237.34  237.38  237.33  237.3300   1515.0
#        2024-01-06 00:56:00+00:00  237.33  237.39  237.32  237.3899   3585.0
#        2024-01-06 00:57:00+00:00  237.35  237.37  237.30  237.3700   4815.0
#        2024-01-06 00:58:00+00:00  237.36  237.40  237.36  237.4000   3756.0
#        2024-01-06 00:59:00+00:00  237.40  237.40  237.39  237.4000   5467.0
#
#                                   trade_count        vwap
# symbol timestamp
# AAPL   2024-01-02 09:00:00+00:00        612.0  190.241493
#        2024-01-02 09:01:00+00:00        425.0  190.088775
#        2024-01-02 09:02:00+00:00        129.0  189.823988
#        2024-01-02 09:03:00+00:00         83.0  189.859107
#        2024-01-02 09:04:00+00:00         87.0  189.916633
# ...                                       ...         ...
# TSLA   2024-01-06 00:55:00+00:00         40.0  237.357500
#        2024-01-06 00:56:00+00:00         71.0  237.365234
#        2024-01-06 00:57:00+00:00         52.0  237.339598
#        2024-01-06 00:58:00+00:00         51.0  237.380920
#        2024-01-06 00:59:00+00:00         70.0  237.392615
#
# [6737 rows x 7 columns]
